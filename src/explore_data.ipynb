# %%
import os
import pandas as pd

# Check if the file exists and try different paths
possible_paths = [
	"../data/simulate_activity.csv",
	"./data/simulate_activity.csv",
	"data/simulate_activity.csv",
	os.path.join(os.path.dirname(os.getcwd()), "data", "simulate_activity.csv")
]

file_path = None
for path in possible_paths:
	if os.path.exists(path):
		file_path = path
		break

if file_path:
	df = pd.read_csv(file_path)
	print(f"File loaded from: {file_path}")
	display(df.head())
	print(f"Shape: {df.shape}")
	df.info()
else:
	print(f"Current working directory: {os.getcwd()}")
	print("File not found. Please check if the file exists at the correct location.")
	print("Looking for: simulate_activity.csv in the data folder")
# Out:
# Current working directory: d:\Major Project\Insider Threat Detection\src
# File not found. Please check if the file exists at the correct location.
# Looking for: simulate_activity.csv in the data folder
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 25
#      22 	print("File not found. Please check if the file exists at the correct location.")
#      23 	print("Looking for: simulate_activity.csv in the data folder")
# ---> 25 df.head()
#      26 df.shape
#      27 df.info()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
